# %%
import pandas as pd

# %%
data=pd.read_csv("Kolhapur_fertilizer_dataset.csv")

# %%
data
# Out:
#      District_Name Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  \
# 0         Kolhapur      Black        75          50        100  6.5      1000
# 1         Kolhapur      Black        80          50        100  6.5      1000
# 2         Kolhapur      Black        85          50        100  6.5      1000
# 3         Kolhapur      Black        90          50        100  6.5      1000
# 4         Kolhapur      Black        95          50        100  6.5      1000
# ...            ...        ...       ...         ...        ...  ...       ...
# 4508          Pune      Black       130          80        150  7.0      1400
# 4509          Pune      Black       135          80        150  7.0      1400
# 4510          Pune      Black       140          80        150  7.0      1400
# 4511          Pune      Black       145          80        150  7.0      1400
# 4512          Pune      Black       150          80        150  7.0      1400
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4513 entries, 0 to 4512
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   District_Name  4513 non-null   object
#  1   Soil_color     4513 non-null   object
#  2   Nitrogen       4513 non-null   int64
#  3   Phosphorus     4513 non-null   int64
#  4   Potassium      4513 non-null   int64
#  5   pH             4513 non-null   float64
#  6   Rainfall       4513 non-null   int64
#  7   Temperature    4513 non-null   int64
#  8   Crop           4513 non-null   object
#  9   Fertilizer     4513 non-null   object
#  10  Link           4513 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 388.0+ KB

# %%
data.isnull().sum()
# Out:
# District_Name    0
# Soil_color       0
# Nitrogen         0
# Phosphorus       0
# Potassium        0
# pH               0
# Rainfall         0
# Temperature      0
# Crop             0
# Fertilizer       0
# Link             0
# dtype: int64

# %%
data.describe(include='all')
# Out:
#        District_Name Soil_color     Nitrogen   Phosphorus    Potassium  \
# count           4513       4513  4513.000000  4513.000000  4513.000000
# unique             5          7          NaN          NaN          NaN
# top         Kolhapur      Black          NaN          NaN          NaN
# freq            1430       2260          NaN          NaN          NaN
# mean             NaN        NaN    95.409927    54.341901    63.595170
# std              NaN        NaN    38.060648    16.551991    35.691911
# min              NaN        NaN    20.000000    10.000000     5.000000
# 25%              NaN        NaN    60.000000    40.000000    40.000000
# 50%              NaN        NaN   105.000000    55.000000    55.000000
# 75%              NaN        NaN   125.000000    65.000000    75.000000
# max              NaN        NaN   150.000000    90.000000   150.000000
#
#                  pH     Rainfall  Temperature       Crop Fertilizer  \
# ...

# %%
data
# Out:
#     Temparature  Humidity   Moisture Soil Type  Crop Type  Nitrogen  \
# 0            26         52        38     Sandy      Maize        37
# 1            29         52        45     Loamy  Sugarcane        12
# 2            34         65        62     Black     Cotton         7
# 3            32         62        34       Red    Tobacco        22
# 4            28         54        46    Clayey      Paddy        35
# ..          ...        ...       ...       ...        ...       ...
# 94           25         50        32    Clayey     Pulses        24
# 95           30         60        27       Red    Tobacco         4
# 96           38         72        51     Loamy      Wheat        39
# 97           36         60        43     Sandy    Millets        15
# 98           29         58        57     Black  Sugarcane        12
#
#     Potassium  Phosphorous Fertilizer Name
# 0           0            0            Urea
# 1           0           36             DAP
# ...

# %%
data.shape
# Out:
# (4513, 11)

# %%
data.columns
# Out:
# Index(['District_Name', 'Soil_color', 'Nitrogen', 'Phosphorus', 'Potassium',
#        'pH', 'Rainfall', 'Temperature', 'Crop', 'Fertilizer', 'Link'],
#       dtype='object')

# %%
data['District_Name'].unique()
# Out:
# array(['Kolhapur', 'Solapur', 'Satara', 'Sangli', 'Pune'], dtype=object)

# %%
data['Soil_color'].unique()
# Out:
# array(['Black', 'Red ', 'Medium Brown', 'Dark Brown', 'Red',
#        'Light Brown', 'Reddish Brown'], dtype=object)

# %%
data['Soil_color'].value_counts()
# Out:
# Soil_color
# Black            2260
# Red               744
# Dark Brown        659
# Red               480
# Reddish Brown     265
# Light Brown        54
# Medium Brown       51
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4513 entries, 0 to 4512
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   District_Name  4513 non-null   object
#  1   Soil_color     4513 non-null   object
#  2   Nitrogen       4513 non-null   int64
#  3   Phosphorus     4513 non-null   int64
#  4   Potassium      4513 non-null   int64
#  5   pH             4513 non-null   float64
#  6   Rainfall       4513 non-null   int64
#  7   Temperature    4513 non-null   int64
#  8   Crop           4513 non-null   object
#  9   Fertilizer     4513 non-null   object
#  10  Link           4513 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 388.0+ KB

# %%
data['Crop'].value_counts()
# Out:
# Crop
# Sugarcane    1010
# Wheat         859
# Cotton        650
# Jowar         394
# Maize         350
# Rice          309
# Groundnut     177
# Tur           126
# Ginger        125
# Grapes        125
# Urad           99
# Moong          99
# Gram           78
# Turmeric       55
# Soybean        45
# Masoor         12
# Name: count, dtype: int64

# %%
data['Crop'].unique()
# Out:
# array(['Sugarcane', 'Jowar', 'Cotton', 'Rice', 'Wheat', 'Groundnut',
#        'Maize', 'Tur', 'Urad', 'Moong', 'Gram', 'Masoor', 'Soybean',
#        'Ginger', 'Turmeric', 'Grapes'], dtype=object)

# %%
data['Fertilizer'].unique()
# Out:
# array(['Urea', 'DAP', 'MOP', '10:26:26 NPK', 'SSP', 'Magnesium Sulphate',
#        '13:32:26 NPK', '12:32:16 NPK', '50:26:26 NPK', '19:19:19 NPK',
#        'Chilated Micronutrient', '18:46:00 NPK', 'Sulphur',
#        '20:20:20 NPK', 'Ammonium Sulphate', 'Ferrous Sulphate',
#        'White Potash', '10:10:10 NPK', 'Hydrated Lime'], dtype=object)

# %%
data['Fertilizer'].value_counts()
# Out:
# Fertilizer
# Urea                      1364
# DAP                        667
# MOP                        571
# 19:19:19 NPK               480
# SSP                        417
# Magnesium Sulphate         215
# 10:26:26 NPK               156
# 50:26:26 NPK               124
# Chilated Micronutrient     108
# 12:32:16 NPK               106
# Ferrous Sulphate            68
# 13:32:26 NPK                66
# Ammonium Sulphate           50
# 10:10:10 NPK                50
# Hydrated Lime               25
# White Potash                19
# 20:20:20 NPK                15
# 18:46:00 NPK                 6
# Sulphur                      6
# Name: count, dtype: int64

# %%
data.duplicated().value_counts()
# Out:
# False    4513
# Name: count, dtype: int64

# %%
import seaborn as sns

# %%
sns.distplot(data['Nitrogen'])
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_27740\1558972008.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Nitrogen'])
# <Axes: xlabel='Nitrogen', ylabel='Density'>

# %%
sns.distplot(data['Phosphorus'])
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_27740\3608483280.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Phosphorus'])
# <Axes: xlabel='Phosphorus', ylabel='Density'>

# %%
sns.distplot(data['Potassium'])
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_27740\3177514820.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Potassium'])
# <Axes: xlabel='Potassium', ylabel='Density'>

# %%
sns.distplot(data['Potassium'])
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_27740\3177514820.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Potassium'])
# <Axes: xlabel='Potassium', ylabel='Density'>

# %%
datac=data.drop(data[['District_Name','Crop','Fertilizer','Link','Soil_color']],axis=1)

# %%
data.columns
# Out:
# Index(['District_Name', 'Soil_color', 'Nitrogen', 'Phosphorus', 'Potassium',
#        'pH', 'Rainfall', 'Temperature', 'Crop', 'Fertilizer', 'Link'],
#       dtype='object')

# %%
datac
# Out:
#       Nitrogen  Phosphorus  Potassium   pH  Rainfall  Temperature
# 0           75          50        100  6.5      1000           20
# 1           80          50        100  6.5      1000           20
# 2           85          50        100  6.5      1000           20
# 3           90          50        100  6.5      1000           20
# 4           95          50        100  6.5      1000           20
# ...        ...         ...        ...  ...       ...          ...
# 4508       130          80        150  7.0      1400           30
# 4509       135          80        150  7.0      1400           30
# 4510       140          80        150  7.0      1400           30
# 4511       145          80        150  7.0      1400           30
# 4512       150          80        150  7.0      1400           30
#
# [4513 rows x 6 columns]

# %%
sns.heatmap(datac.corr(),annot=True)
# Out:
# <Axes: >

# %%
data
# Out:
#      District_Name Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  \
# 0         Kolhapur      Black        75          50        100  6.5      1000
# 1         Kolhapur      Black        80          50        100  6.5      1000
# 2         Kolhapur      Black        85          50        100  6.5      1000
# 3         Kolhapur      Black        90          50        100  6.5      1000
# 4         Kolhapur      Black        95          50        100  6.5      1000
# ...            ...        ...       ...         ...        ...  ...       ...
# 4508          Pune      Black       130          80        150  7.0      1400
# 4509          Pune      Black       135          80        150  7.0      1400
# 4510          Pune      Black       140          80        150  7.0      1400
# 4511          Pune      Black       145          80        150  7.0      1400
# 4512          Pune      Black       150          80        150  7.0      1400
#
# ...

# %%
data['District_Name'].unique()
# Out:
# array(['Kolhapur', 'Solapur', 'Satara', 'Sangli', 'Pune'], dtype=object)

# %%
District_Name_map={'Kolhapur':1,'Solapur':2,'Satara':3,'Sangli':4,'Pune':5}

# %%
data[data['Soil_color'] == 'Red']
# Out:
#      District_Name Soil_color  Nitrogen  Phosphorus  Potassium   pH  Rainfall  \
# 1325      Kolhapur        Red        40          20         20  5.5       300
# 1326      Kolhapur        Red        45          20         20  5.5       300
# 1327      Kolhapur        Red        50          20         20  5.5       300
# 1328      Kolhapur        Red        40          25         25  6.0       400
# 1329      Kolhapur        Red        45          25         25  6.0       400
# ...            ...        ...       ...         ...        ...  ...       ...
# 4209          Pune        Red        25          35         20  6.0       800
# 4210          Pune        Red        30          35         20  6.0       800
# 4211          Pune        Red        20          40         25  6.5       900
# 4212          Pune        Red        25          40         25  6.5       900
# 4213          Pune        Red        30          40         25  6.5       900
#
# ...

# %%
data['Soil_color']=data['Soil_color'].str.replace("Red ","Red")

# %%
data['Soil_color'].unique()
# Out:
# array(['Black', 'Red', 'Medium Brown', 'Dark Brown', 'Light Brown',
#        'Reddish Brown'], dtype=object)

# %%
soil_color_map= {
    'Black': 1,
    'Red': 2,
    'Medium Brown': 3,
    'Dark Brown': 4,
    'Light Brown': 5,
    'Reddish Brown': 6
}

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4513 entries, 0 to 4512
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   District_Name  4513 non-null   object
#  1   Soil_color     4513 non-null   object
#  2   Nitrogen       4513 non-null   int64
#  3   Phosphorus     4513 non-null   int64
#  4   Potassium      4513 non-null   int64
#  5   pH             4513 non-null   float64
#  6   Rainfall       4513 non-null   int64
#  7   Temperature    4513 non-null   int64
#  8   Crop           4513 non-null   object
#  9   Fertilizer     4513 non-null   object
#  10  Link           4513 non-null   object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 388.0+ KB

# %%
data['Crop'].unique()
# Out:
# array(['Sugarcane', 'Jowar', 'Cotton', 'Rice', 'Wheat', 'Groundnut',
#        'Maize', 'Tur', 'Urad', 'Moong', 'Gram', 'Masoor', 'Soybean',
#        'Ginger', 'Turmeric', 'Grapes'], dtype=object)

# %%
crop_mapping= {
    'Sugarcane': 1, 'Jowar': 2, 'Cotton': 3, 'Rice': 4, 'Wheat': 5,
    'Groundnut': 6, 'Maize': 7, 'Tur': 8, 'Urad': 9, 'Moong': 10,
    'Gram': 11, 'Masoor': 12, 'Soybean': 13, 'Ginger': 14, 
    'Turmeric': 15, 'Grapes': 16
}

# %%
data['Fertilizer'].unique()
# Out:
# array(['Urea', 'DAP', 'MOP', '10:26:26 NPK', 'SSP', 'Magnesium Sulphate',
#        '13:32:26 NPK', '12:32:16 NPK', '50:26:26 NPK', '19:19:19 NPK',
#        'Chilated Micronutrient', '18:46:00 NPK', 'Sulphur',
#        '20:20:20 NPK', 'Ammonium Sulphate', 'Ferrous Sulphate',
#        'White Potash', '10:10:10 NPK', 'Hydrated Lime'], dtype=object)

# %%
fertilizer_mapping = {
    'Urea': 1, 'DAP': 2, 'MOP': 3, '10:26:26 NPK': 4, 'SSP': 5, 
    'Magnesium Sulphate': 6, '13:32:26 NPK': 7, '12:32:16 NPK': 8, 
    '50:26:26 NPK': 9, '19:19:19 NPK': 10, 'Chilated Micronutrient': 11, 
    '18:46:00 NPK': 12, 'Sulphur': 13, '20:20:20 NPK': 14, 
    'Ammonium Sulphate': 15, 'Ferrous Sulphate': 16, 'White Potash': 17, 
    '10:10:10 NPK': 18, 'Hydrated Lime': 19
}

# %%
data['Fertilizer']=data['Fertilizer'].map(fertilizer_mapping)
data['Crop']=data['Crop'].map(crop_mapping)
data['Soil_color']=data['Soil_color'].map(soil_color_map)
data['District_Name']=data['District_Name'].map(District_Name_map)

# %%
data
# Out:
#       District_Name  Soil_color  Nitrogen  Phosphorus  Potassium   pH  \
# 0                 1           1        75          50        100  6.5
# 1                 1           1        80          50        100  6.5
# 2                 1           1        85          50        100  6.5
# 3                 1           1        90          50        100  6.5
# 4                 1           1        95          50        100  6.5
# ...             ...         ...       ...         ...        ...  ...
# 4508              5           1       130          80        150  7.0
# 4509              5           1       135          80        150  7.0
# 4510              5           1       140          80        150  7.0
# 4511              5           1       145          80        150  7.0
# 4512              5           1       150          80        150  7.0
#
#       Rainfall  Temperature  Crop  Fertilizer                          Link
# ...

# %%
data=data.drop(columns=['Link'])

# %%
data
# Out:
#       District_Name  Soil_color  Nitrogen  Phosphorus  Potassium   pH  \
# 0                 1           1        75          50        100  6.5
# 1                 1           1        80          50        100  6.5
# 2                 1           1        85          50        100  6.5
# 3                 1           1        90          50        100  6.5
# 4                 1           1        95          50        100  6.5
# ...             ...         ...       ...         ...        ...  ...
# 4508              5           1       130          80        150  7.0
# 4509              5           1       135          80        150  7.0
# 4510              5           1       140          80        150  7.0
# 4511              5           1       145          80        150  7.0
# 4512              5           1       150          80        150  7.0
#
#       Rainfall  Temperature  Crop  Fertilizer
# 0         1000           20     1           1
# ...

# %%
x=data.drop(columns=['Fertilizer'])

# %%
y=data['Fertilizer']

# %%
x
# Out:
#       District_Name  Soil_color  Nitrogen  Phosphorus  Potassium   pH  \
# 0                 1           1        75          50        100  6.5
# 1                 1           1        80          50        100  6.5
# 2                 1           1        85          50        100  6.5
# 3                 1           1        90          50        100  6.5
# 4                 1           1        95          50        100  6.5
# ...             ...         ...       ...         ...        ...  ...
# 4508              5           1       130          80        150  7.0
# 4509              5           1       135          80        150  7.0
# 4510              5           1       140          80        150  7.0
# 4511              5           1       145          80        150  7.0
# 4512              5           1       150          80        150  7.0
#
#       Rainfall  Temperature  Crop
# 0         1000           20     1
# 1         1000           20     1
# ...

# %%
y
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 4508    3
# 4509    3
# 4510    3
# 4511    3
# 4512    3
# Name: Fertilizer, Length: 4513, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test = train_test_split(x, y, test_size=0.2, random_state=20)

# %%
X_train.shape
# Out:
# (3610, 9)

# %%
X_test.shape
# Out:
# (903, 9)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
accuracy = model.score(X_test, y_test)  
print("Model Accuracy:", accuracy)
# Out:
# Model Accuracy: 0.9501661129568106

# %%
prediction= model.predict([[1,1,80,50,100,6.5,1000,20,1]])  
print("Predicted Output:", prediction)
# Out:
# Predicted Output: [1]
# C:\Users\acer\anacondasomu\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
# Out:
#       District_Name  Soil_color  Nitrogen  Phosphorus  Potassium   pH  \
# 0                 1           1        75          50        100  6.5
# 1                 1           1        80          50        100  6.5
# 2                 1           1        85          50        100  6.5
# 3                 1           1        90          50        100  6.5
# 4                 1           1        95          50        100  6.5
# ...             ...         ...       ...         ...        ...  ...
# 4508              5           1       130          80        150  7.0
# 4509              5           1       135          80        150  7.0
# 4510              5           1       140          80        150  7.0
# 4511              5           1       145          80        150  7.0
# 4512              5           1       150          80        150  7.0
#
#       Rainfall  Temperature  Crop
# 0         1000           20     1
# 1         1000           20     1
# ...

# %%
fertilizer_mapping ['Urea']
# Out:
# 1

# %%
fertilizer_mapping = {
    'Urea': 1, 'DAP': 2, 'MOP': 3, '10:26:26 NPK': 4, 'SSP': 5, 
    'Magnesium Sulphate': 6, '13:32:26 NPK': 7, '12:32:16 NPK': 8, 
    '50:26:26 NPK': 9, '19:19:19 NPK': 10, 'Chilated Micronutrient': 11, 
    '18:46:00 NPK': 12, 'Sulphur': 13, '20:20:20 NPK': 14, 
    'Ammonium Sulphate': 15, 'Ferrous Sulphate': 16, 'White Potash': 17, 
    '10:10:10 NPK': 18, 'Hydrated Lime': 19
}

# %%
len(fertilizer_mapping)
# Out:
# 19

# %%
for key, value in fertilizer_mapping.items():
    if(prediction==value):
        print(f"this is the your fertilizer recommendation {key}")
# Out:
# this is the your fertilizer recommendation Urea

# %%
fertilizer_mapping.keys()
# Out:
# dict_keys(['Urea', 'DAP', 'MOP', '10:26:26 NPK', 'SSP', 'Magnesium Sulphate', '13:32:26 NPK', '12:32:16 NPK', '50:26:26 NPK', '19:19:19 NPK', 'Chilated Micronutrient', '18:46:00 NPK', 'Sulphur', '20:20:20 NPK', 'Ammonium Sulphate', 'Ferrous Sulphate', 'White Potash', '10:10:10 NPK', 'Hydrated Lime'])
