# %%
import pandas as pd

# %%
mydict={
    "iq":[90,100,110,120,80],
    "cgpa":[8,7,6,9,5],
    "salary":[3,4,8,6,3]
}

# %%
data=pd.DataFrame(mydict)

# %%
data
# Out:
#     iq  cgpa  salary
# 0   90     8       3
# 1  100     7       4
# 2  110     6       8
# 3  120     9       6
# 4   80     5       3

# %%
x=data[["iq","cgpa"]]
y=data.salary

# %%
y
# Out:
# 0    3
# 1    4
# 2    8
# 3    6
# 4    3
# Name: salary, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model=DecisionTreeClassifier()

# %%
model.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
model.score(x,y)
# Out:
# 1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import tree

# %%
fig,ax=plt.subplots(figsize=(10,10))
tree.plot_tree(model,filled=True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.rand(100,1)-0.5
y=3*x[:,0]**2+0.05*np.random.randn(100)

# %%
x
# Out:
# array([[ 0.01663257],
#        [ 0.19056479],
#        [-0.3181661 ],
#        [-0.26457306],
#        [-0.44027664],
#        [ 0.18753528],
#        [-0.34829849],
#        [ 0.05831734],
#        [-0.11084089],
#        [-0.46397647],
#        [ 0.20756264],
#        [-0.35282013],
#        [-0.06550883],
#        [-0.2965252 ],
#        [ 0.19148899],
#        [ 0.15731617],
#        [-0.06276734],
#        [ 0.44731418],
#        [-0.32149646],
#        [ 0.09217194],
#        [-0.02418243],
#        [-0.12784427],
#        [-0.2096931 ],
#        [ 0.27014415],
#        [ 0.0457281 ],
#        [ 0.15035891],
#        [-0.02103895],
#        [ 0.46512138],
#        [ 0.16239026],
#        [ 0.14193789],
#        [ 0.22606458],
#        [-0.22175855],
#        [ 0.30057451],
#        [-0.492814  ],
#        [-0.03829729],
#        [-0.42249151],
#        [ 0.46573301],
#        [-0.2335577 ],
#        [-0.24576149],
#        [-0.30375074],
#        [ 0.29333093],
#        [-0.18920655],
#        [ 0.49184163],
#        [ 0.04344856],
#        [ 0.10839057],
#        [-0.46375118],
#        [-0.00142063],
#        [ 0.03311994],
#        [ 0.417217  ],
#        [ 0.3044049 ],
#        [ 0.12496805],
#        [ 0.28444654],
#        [-0.19721924],
#        [ 0.44075493],
#        [ 0.28131727],
#        [-0.04709308],
#        [-0.27390112],
#        [ 0.23720116],
#        [ 0.32901903],
#        [ 0.18998059],
#        [-0.36879063],
#        [-0.11305229],
#        [ 0.39618547],
#        [ 0.0381223 ],
#        [ 0.2208618 ],
#        [-0.47235669],
#        [ 0.4047039 ],
#        [ 0.42571366],
#        [-0.23735088],
#        [-0.48295207],
#        [ 0.17376132],
#        [ 0.30459088],
#        [ 0.27737593],
#        [-0.03818084],
#        [-0.45142789],
#        [-0.11550808],
#        [-0.49843671],
#        [ 0.1798147 ],
#        [ 0.04086622],
#        [ 0.49807608],
#        [-0.26885037],
#        [-0.13585602],
#        [-0.4763188 ],
#        [ 0.43259898],
#        [ 0.4426286 ],
#        [ 0.10959221],
#        [-0.10654147],
#        [-0.45239988],
#        [ 0.33718987],
#        [ 0.17668013],
#        [-0.25070757],
#        [ 0.1259057 ],
#        [-0.20799806],
#        [ 0.3165813 ],
#        [-0.38313774],
#        [-0.49100455],
#        [-0.09653451],
#        [-0.45545641],
#        [ 0.19064821],
#        [ 0.32100409]])

# %%
y
# Out:
# array([ 0.06127439,  0.17701885,  0.252998  ,  0.25178127,  0.63631462,
#         0.12576195,  0.34746628,  0.05897646, -0.0488175 ,  0.57563683,
#         0.14838808,  0.37275553,  0.07623372,  0.2652191 ,  0.11819155,
#         0.12203073,  0.13579303,  0.55818419,  0.27953938,  0.02048558,
#        -0.04421469,  0.06505597,  0.12826445,  0.27516579,  0.02039887,
#         0.04864818, -0.0058921 ,  0.58332777,  0.0871728 ,  0.05137041,
#         0.21859667,  0.15649449,  0.25336792,  0.73687523, -0.05305596,
#         0.55671725,  0.59390962,  0.05043129,  0.23966314,  0.22416919,
#         0.29021046,  0.11394013,  0.73282513, -0.01021875,  0.10852562,
#         0.56383938, -0.02215398,  0.00712594,  0.44608865,  0.24033438,
#        -0.03741594,  0.21260244,  0.1732923 ,  0.60515062,  0.30791792,
#        -0.01061039,  0.22720293,  0.25022261,  0.30805421,  0.06343228,
#         0.36442694, -0.03891753,  0.45221001,  0.07176396,  0.13305105,
#         0.66630042,  0.45386777,  0.43648013,  0.20038371,  0.72906527,
#         0.15828517,  0.30977302,  0.19319456, -0.05153174,  0.46631933,
#         0.06017376,  0.84702971,  0.1285875 ,  0.00530244,  0.7123345 ,
#         0.19815407,  0.10908552,  0.65368291,  0.61534123,  0.49562447,
#        -0.02098348,  0.00587641,  0.58657435,  0.40268787,  0.12080351,
#         0.17757494,  0.06017749,  0.0345319 ,  0.41723085,  0.39064739,
#         0.77859303,  0.04447953,  0.66204281,  0.21182194,  0.35498443])

# %%
df=pd.DataFrame()

# %%
df['x']=x.reshape(100)

# %%
df['y']=y

# %%
df
# Out:
#            x         y
# 0   0.016633  0.061274
# 1   0.190565  0.177019
# 2  -0.318166  0.252998
# 3  -0.264573  0.251781
# 4  -0.440277  0.636315
# ..       ...       ...
# 95 -0.491005  0.778593
# 96 -0.096535  0.044480
# 97 -0.455456  0.662043
# 98  0.190648  0.211822
# 99  0.321004  0.354984
#
# [100 rows x 2 columns]

# %%
plt.scatter(df['x'],df['y'])
plt.show()

# %%
df.head()
# Out:
#           x         y
# 0 -0.061112  0.086087
# 1  0.141278  0.122807
# 2 -0.358495  0.423933
# 3 -0.060499  0.042967
# 4  0.342720  0.300950

# %%
df['pre1']=df['y'].mean()

# %%
df
# Out:
#            x         y      pre1
# 0   0.016633  0.061274  0.258891
# 1   0.190565  0.177019  0.258891
# 2  -0.318166  0.252998  0.258891
# 3  -0.264573  0.251781  0.258891
# 4  -0.440277  0.636315  0.258891
# ..       ...       ...       ...
# 95 -0.491005  0.778593  0.258891
# 96 -0.096535  0.044480  0.258891
# 97 -0.455456  0.662043  0.258891
# 98  0.190648  0.211822  0.258891
# 99  0.321004  0.354984  0.258891
#
# [100 rows x 3 columns]

# %%
df['res1']=df['y']-df['pre1']

# %%
df
# Out:
#            x         y      pre1      res1
# 0   0.016633  0.061274  0.258891 -0.197617
# 1   0.190565  0.177019  0.258891 -0.081872
# 2  -0.318166  0.252998  0.258891 -0.005893
# 3  -0.264573  0.251781  0.258891 -0.007110
# 4  -0.440277  0.636315  0.258891  0.377424
# ..       ...       ...       ...       ...
# 95 -0.491005  0.778593  0.258891  0.519702
# 96 -0.096535  0.044480  0.258891 -0.214411
# 97 -0.455456  0.662043  0.258891  0.403152
# 98  0.190648  0.211822  0.258891 -0.047069
# 99  0.321004  0.354984  0.258891  0.096093
#
# [100 rows x 4 columns]

# %%
plt.scatter(df['x'],df['y'])
plt.plot(df['x'],df['pre1'],color="red")

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
tree1=DecisionTreeRegressor(max_leaf_nodes=8)

# %%
tree1.fit(df['x'].values.reshape(100,1),df['res1'].values)
# Out:
# DecisionTreeRegressor(max_leaf_nodes=8)

# %%
from sklearn.tree import plot_tree
plot_tree(tree1,filled=True)
plt.show()
